# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.optimize import minimize
f = lambda x:(x[0]-2)**2 + 4*(x[1]-6)**2
cons = ({'type':'ineq','fun':lambda x: -6*x[0]-3*(x[1]+1)**2+12})
bnds = ((0,None),(0,None))
x0 = (2,0)
res = minimize(f,x0, bounds=bnds, constraints= cons)
res
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 104.00000000000075
#        x: [ 0.000e+00  1.000e+00]
#      nit: 5
#      jac: [-4.000e+00 -4.000e+01]
#     nfev: 16
#     njev: 5

# %%
res2 = minimize(f,x0)
res2
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 1.7224960722968393e-15
#         x: [ 2.000e+00  6.000e+00]
#       nit: 3
#       jac: [ 1.490e-08  2.256e-07]
#  hess_inv: [[ 1.000e+00  0.000e+00]
#             [ 0.000e+00  1.250e-01]]
#      nfev: 12
#      njev: 4

# %%
res3 = minimize(f,x0)
res3
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 1.7224960722968393e-15
#         x: [ 2.000e+00  6.000e+00]
#       nit: 3
#       jac: [ 1.490e-08  2.256e-07]
#  hess_inv: [[ 1.000e+00  0.000e+00]
#             [ 0.000e+00  1.250e-01]]
#      nfev: 12
#      njev: 4

# %%
from mpl_toolkits.mplot3d import Axes3D

f = lambda x1, x2:(x1-2)**2 + 4*(x2-6)**2
x2 = np.linspace(-1.5,1.5,100)
x1 = np.linspace(-1,5,100)
X,Y = np.meshgrid(x1,x2)
F = f(X,Y)
fig = plt.figure(figsize=(15,15))
ax=plt.subplot(1,2,1,projection='3d')
ax.scatter3D(1,1,f(1,1),c='black',marker='*',s=100)
surf = ax.plot_surface(X,Y,F, cmap='gist_rainbow')
# ax1=plt.subplot(1,2,2,projection='3d')
# ax1.scatter3D(1,1,f(1,1),c='black',marker='*',s=100)
# contr=ax1.contour(X,Y,F,cmap='gist_rainbow')
# ax1.set_title('Contour Plot')
fig.colorbar(surf,shrink=0.4,aspect=20)
ax.set_xlabel('x1', labelpad=10)
ax.set_ylabel('x2', labelpad=30)
ax.set_zlabel('f(X)', labelpad=10)
plt.show()

# %%
f = lambda x1, x2:(x1-2)**2 + 4*(x2-6)**2
x2 = np.linspace(-1.5,1.5,100)
x1 = np.linspace(-1,5,100)
X,Y = np.meshgrid(x1,x2)
F = f(X,Y)
fig = plt.figure(figsize=(15,15))
levels=np.arange(0.0,12,0.4)
contr=plt.contour(X,Y,F,cmap='gist_rainbow')
plt.clabel(cp)
plt.plot(x, (x+2)/2, 'k:', linewidth=1)
plt.plot(res.x[0],res.x[1],c='r',marker='o')
plt.plot(res2.x[0],res2.x[1],c='b',marker='x')
plt.plot(res3.x[0],res3.x[1],c='g',marker='*',markersize=10)
plt.plot(x, (-x+6)/2, 'k:', linewidth=1)
plt.axis([-1,4,0,4])
plt.show()
